# %% [markdown]
# I need to verify that Next.js Server Components can pass Date objects to Client Components.
# Actually, Next.js *can* pass Date objects to client components, they are serialized automatically.
# However, just to be safe and avoid serialization warnings (which sometimes happen with non-plain objects in some versions), I might convert to string. But `Date` is supported.
#
# Let's modify `src/app/tutors/apply/page.tsx`.
